# %%
import numpy as np
import pandas as pd

import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import acquire as ac
import prepare as pr

# %%
blogs = ac.get_blog_articles(urls=["https://codeup.com/codeups-data-science-career-accelerator-is-here/",
                       "https://codeup.com/data-science-myths/",
                       "https://codeup.com/data-science-vs-data-analytics-whats-the-difference/",
                       "https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/",
                       "https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/"])
blogs
# Out:
# [{'title': 'Codeup’s Data Science Career Accelerator is Here! - Codeup',
# ...

# %%
blogs = pr.prepare_article_data(blogs)
blogs = pd.DataFrame(blogs)
blogs
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is He...
# 1                        Data Science Myths - Codeup
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3  10 Tips to Crush It at the SA Tech Job Fair - ...
# 4  Competitor Bootcamps Are Closing. Is the Model...
#
#                                     original_content  \
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie GiustData Scien...
# 2  By Dimitri AntoniouA week ago, Codeup launched...
# 3  10 Tips to Crush It at the SA Tech Job FairSA ...
# 4  Competitor Bootcamps Are Closing. Is the Model...
#
#                                              stemmed  \
# 0  the rumor are true the time ha arriv codeup ha...
# 1  by dimitri antoni and maggi giustdata scienc b...
# 2  by dimitri antonioua week ago codeup launch ou...
# 3  10 tip to crush it at the sa tech job fairsa t...
# ...

# %%
news_articles = ac.get_news_articles(categories=["business", "sports", "technology", "entertainment"])
news_articles
# Out:
# [{'title': "US firm buys Serum Institute parent's Czech unit to make Covid-19 vaccine",
#   'original_content': "US biotech firm Novavax has announced it's buying Czech Republic-based Praha Vaccines, a unit of Cyrus Poonawalla Group, which also owns Serum Institute of India, for ₹1,270 crore. The facility is expected to provide an annual capacity of over 1 billion doses of antigen starting in 2021 for Novavax's Covid-19 vaccine candidate. Novavax currently has no product on the market.",
#   'category': 'business'},
#  {'title': 'Microsoft in talks to buy 2.5% stake in Jio for $2 billion: Report',
# ...

# %%
news_articles = pr.prepare_article_data(news_articles)
news_articles = pd.DataFrame(news_articles)
news_articles
# Out:
#                                                 title  \
# 0   US firm buys Serum Institute parent's Czech un...
# 1   Microsoft in talks to buy 2.5% stake in Jio fo...
# 2   Google in talks to buy 5% stake in Vodafone Id...
# 3   GE to sell its 129-year-old lightbulb business...
# 4   Govt to stop issuing 7.75% savings bonds from ...
# ..                                                ...
# 95  Digital rights of 'Laxmmi Bomb' sold for ₹125 ...
# 96  I miss my maid because I took her for granted:...
# 97  Can't plan baby in such tension, it's risky to...
# 98  John is almost a superhero like Hulk in Satyam...
# 99  'Pretty Little Liars' actress Sasha Pieterse p...
#
#                                      original_content       category  \
# 0   US biotech firm Novavax has announced it's buy...       business
# 1   Microsoft is in talks with Mukesh Ambani-led R...       business
# 2   Google is exploring an investment in Vodafone ...       business
# ...
